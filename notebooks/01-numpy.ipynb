# %% [markdown]
# # Week 1 - NumPy
# Go through the relevant parts of the NumPy documentation.
#
# Focus only on:
# - arrays
# - shapes
# - indexing/slicing
# - broadcasting
# - vectorization
# - matrix multiplication
# - aggregations
# - random numbers
